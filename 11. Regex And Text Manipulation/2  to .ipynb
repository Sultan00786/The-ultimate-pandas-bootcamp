# %% [markdown]
# ### 2. Our Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# url: https://andybek.com/pandas-marathon

# %%
boston = pd.read_csv('https://andybek.com/pandas-marathon')
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           1000 non-null   object
#  1   Age            1000 non-null   int64
#  2   M/F            1000 non-null   object
#  3   City           1000 non-null   object
#  4   State          807 non-null    object
#  5   Country        1000 non-null   object
#  6   Official Time  1000 non-null   object
#  7   Overall        1000 non-null   int64
#  8   Gender         1000 non-null   int64
#  9   Years Ran      315 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 78.3+ KB

# %% [markdown]
# ### 3. String manupulation in py

# %% [markdown]
# #### **Agenda**:
#     - len
#     - center
#     - startswith, endswith
#     - the 'in' operator
#     - list comprehensions

# %%
s = 'Hellow my self sultan'

# %%
len(s)
# Out:
# 21

# %%
s.center(50, '*')
# Out:
# '**************Hellow my self sultan***************'

# %%
s.center(23, '*')
# Out:
# '*Hellow my self sultan*'

# %%
s.center(20, '*')
# Out:
# 'Hellow my self sultan'

# %%
s
# Out:
# 'Hellow my self sultan'

# %%
s.startswith('H')
# Out:
# True

# %%
s.startswith('Hellow ')
# Out:
# True

# %%
s.endswith('n')
# Out:
# True

# %%
s.endswith('tan')
# Out:
# True

# %%
# 'in' operator for check includes

# %%
s
# Out:
# 'Hellow my self sultan'

# %%
'my' in s
# Out:
# True

# %%
'Tultan' in s
# Out:
# False

# %% [markdown]
# #### - list comprehensions
#
# ##### but it throws error if NA values present in list or array

# %%
names = ["Sultan", "Rahul", "Amit", "Priya", "Neha"]

# %%
[len(n) for n in names]
# Out:
# [6, 5, 4, 5, 4]

# %%
['t' in n for n in names]
# Out:
# [True, False, True, False, False]

# %%
[n.center(10,'_') for n in names]
# Out:
# ['__Sultan__', '__Rahul___', '___Amit___', '__Priya___', '___Neha___']

# %% [markdown]
# ### 4. Vectorized String Operation In pd

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran
# 0        1       1       NaN
# 1        2       2       NaN
# 2        3       3       NaN
# 3        4       4       NaN
# 4        5       5      2015

# %%
boston.Name.iloc[0]
# Out:
# ' Kirui, Geoffrey '

# %%
len(boston.Name.iloc[0])
# Out:
# 17

# %%
boston.Name
# Out:
# 0         Kirui, Geoffrey
# 1           Rupp, Galen
# 2          Osako, Suguru
# 3         Biwott, Shadrack
# 4           Chebet, Wilson
#               ...
# 995           Larosa, Mark
# 996    Williamson, Jerry A
# 997        Mccue, Daniel T
# 998           Larosa, John
# 999         Sanchez, Sam R
# Name: Name, Length: 1000, dtype: object

# %%
len(boston.Name)
# Out:
# 1000

# %%
boston.Name.str.len()
# Out:
# 0      17
# 1      14
# 2      15
# 3      16
# 4      14
#        ..
# 995    12
# 996    19
# 997    15
# 998    12
# 999    14
# Name: Name, Length: 1000, dtype: int64

# %%
boston.Name.str.startswith("A")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Name, Length: 1000, dtype: bool

# %%
boston.Name.str.endswith("A")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: Name, Length: 1000, dtype: bool

# %%
boston.Name.str.center(20, "_")
# Out:
# 0      _ Kirui, Geoffrey __
# 1      ___Rupp, Galen   ___
# 2      __Osako, Suguru  ___
# 3      __Biwott, Shadrack__
# 4      ___Chebet, Wilson___
#                ...
# 995    ____Larosa, Mark____
# 996    Williamson, Jerry A_
# 997    __Mccue, Daniel T___
# 998    ____Larosa, John____
# 999    ___Sanchez, Sam R___
# Name: Name, Length: 1000, dtype: object

# %% [markdown]
# ### 5. Cas Operation

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran
# 0        1       1       NaN
# 1        2       2       NaN
# 2        3       3       NaN
# 3        4       4       NaN
# 4        5       5      2015

# %%
boston.City
# Out:
# 0           Keringet
# 1           Portland
# 2       Machida-City
# 3      Mammoth Lakes
# 4           Marakwet
#            ...
# 995    North Andover
# 996          Raleigh
# 997        Arlington
# 998          Danbury
# 999         Santa Fe
# Name: City, Length: 1000, dtype: object

# %%
boston.City.str.lower()
# Out:
# 0           keringet
# 1           portland
# 2       machida-city
# 3      mammoth lakes
# 4           marakwet
#            ...
# 995    north andover
# 996          raleigh
# 997        arlington
# 998          danbury
# 999         santa fe
# Name: City, Length: 1000, dtype: object

# %%
boston.City.str.upper()
# Out:
# 0           KERINGET
# 1           PORTLAND
# 2       MACHIDA-CITY
# 3      MAMMOTH LAKES
# 4           MARAKWET
#            ...
# 995    NORTH ANDOVER
# 996          RALEIGH
# 997        ARLINGTON
# 998          DANBURY
# 999         SANTA FE
# Name: City, Length: 1000, dtype: object

# %%
boston.City.str.title()
# Out:
# 0           Keringet
# 1           Portland
# 2       Machida-City
# 3      Mammoth Lakes
# 4           Marakwet
#            ...
# 995    North Andover
# 996          Raleigh
# 997        Arlington
# 998          Danbury
# 999         Santa Fe
# Name: City, Length: 1000, dtype: object

# %% [markdown]
# ### 6. Finding Characters and Words

# %% [markdown]
# #### **Agenda**:
#     - find()
#     - rfind() in py and pd

# %%
s
# Out:
# 'Hellow my self sultan'

# %%
s.find('w')
# Out:
# 5

# %%
s.find('self')
# Out:
# 10

# %%
s.find('z')
# Out:
# -1

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran
# 0        1       1       NaN
# 1        2       2       NaN
# 2        3       3       NaN
# 3        4       4       NaN
# 4        5       5      2015

# %%
boston.Name
# Out:
# 0         Kirui, Geoffrey
# 1           Rupp, Galen
# 2          Osako, Suguru
# 3         Biwott, Shadrack
# 4           Chebet, Wilson
#               ...
# 995           Larosa, Mark
# 996    Williamson, Jerry A
# 997        Mccue, Daniel T
# 998           Larosa, John
# 999         Sanchez, Sam R
# Name: Name, Length: 1000, dtype: object

# %% [markdown]
# ##### Find '**Mark**' in all name

# %%
boston.Name.str.find('Mark')
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 995    8
# 996   -1
# 997   -1
# 998   -1
# 999   -1
# Name: Name, Length: 1000, dtype: int64

# %%
condition = boston.Name.str.find('Mark') != -1
boston[condition]
# Out:
#                       Name  Age M/F            City State Country  \
# 88           Jones, Mark T   30   M         Boulder    CO     USA
# 296            Puleo, Mark   21   M          Woburn    MA     USA
# 531       Rabasco, Mark T.   22   M      Pittsfield    MA     USA
# 609  Heerensperger, Mark E   38   M          Austin    TX     USA
# 758          Angus, Mark E   37   M         Toronto    ON     CAN
# 759       Buckner, Mark L.   33   M  Salt Lake City    UT     USA
# 880             Egge, Mark   30   M        Cheyenne    WY     USA
# 987       Cucuzzella, Mark   50   M   Shepherdstown    WV     USA
# 995           Larosa, Mark   38   M   North Andover    MA     USA
#
#     Official Time  Overall  Gender  Years Ran
# 88        2:33:56       89      79        NaN
# 296       2:44:02      297     271        NaN
# 531       2:49:17      532     495        NaN
# 609       2:50:30      610     570       2016
# 758       2:52:56      759     715        NaN
# ...

# %%
s
# Out:
# 'Hellow my self sultan'

# %%
s.find('w')
# Out:
# 5

# %%
s.rfind('w')
# Out:
# 5

# %%
s.find('s')
# Out:
# 10

# %%
s.rfind('s')
# Out:
# 15

# %% [markdown]
# ### 7. Strips And Whitespace

# %% [markdown]
# #### **Agenda**:
#     - isspace()
#     - lstrip()
#     - rstrip()
#     - strip()

# %%
' '.isspace()
# Out:
# True

# %%
'\n'.isspace()
# Out:
# True

# %%
'\t'.isspace()
# Out:
# True

# %%
l_space = '     this is a pandas course'

# %%
r_space = 'we cover plenty of python tools     '

# %%
both_space = ' the name is: BOND \t JAMES BOND \n\n     '

# %%
both_space
# Out:
# ' the name is: BOND \t JAMES BOND \n\n     '

# %%
print(both_space)
# Out:
#  the name is: BOND 	 JAMES BOND

# %% [markdown]
# ##### Now time to clean up the spaces

# %%
l_space.lstrip()
# Out:
# 'this is a pandas course'

# %%
r_space.rstrip()
# Out:
# 'we cover plenty of python tools'

# %%
both_space.strip()
# Out:
# 'the name is: BOND \t JAMES BOND'

# %%
both_space.strip() ## '\t' not get remove, we will cover in future fuck's
# Out:
# 'the name is: BOND \t JAMES BOND'

# %% [markdown]
# ##### Now time to clean up the spaces from name of boston df

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           1000 non-null   object
#  1   Age            1000 non-null   int64
#  2   M/F            1000 non-null   object
#  3   City           1000 non-null   object
#  4   State          807 non-null    object
#  5   Country        1000 non-null   object
#  6   Official Time  1000 non-null   object
#  7   Overall        1000 non-null   int64
#  8   Gender         1000 non-null   int64
#  9   Years Ran      315 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 78.3+ KB

# %%
boston.Name
# Out:
# 0         Kirui, Geoffrey
# 1           Rupp, Galen
# 2          Osako, Suguru
# 3         Biwott, Shadrack
# 4           Chebet, Wilson
#               ...
# 995           Larosa, Mark
# 996    Williamson, Jerry A
# 997        Mccue, Daniel T
# 998           Larosa, John
# 999         Sanchez, Sam R
# Name: Name, Length: 1000, dtype: object

# %%
boston.Name.iloc[0]
# Out:
# ' Kirui, Geoffrey '

# %%
boston.Name.str.strip()
# Out:
# 0          Kirui, Geoffrey
# 1              Rupp, Galen
# 2            Osako, Suguru
# 3         Biwott, Shadrack
# 4           Chebet, Wilson
#               ...
# 995           Larosa, Mark
# 996    Williamson, Jerry A
# 997        Mccue, Daniel T
# 998           Larosa, John
# 999         Sanchez, Sam R
# Name: Name, Length: 1000, dtype: object

# %%
boston.Name.str.strip().iloc[0]
# Out:
# 'Kirui, Geoffrey'

# %%
boston.Name = boston.Name.str.strip()

# %%
boston.Name.iloc[0]
# Out:
# 'Kirui, Geoffrey'

# %% [markdown]
# ### 7. Strips And Whitespace
