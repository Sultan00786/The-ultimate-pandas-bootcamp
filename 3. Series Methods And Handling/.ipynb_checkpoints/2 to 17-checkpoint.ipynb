# %% [markdown]
# ## 2. Reading In Data With read_csv()

# %%
import pandas as pd

# %%
pd.read_csv('https://www.andybek.com/pandas-drinks')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             NaN
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
pd.read_csv('https://www.andybek.com/pandas-drinks', usecols=['country', 'wine_servings'])
# Out:
#          country  wine_servings
# 0    Afghanistan            NaN
# 1        Albania           54.0
# 2        Algeria           14.0
# 3        Andorra          312.0
# 4         Angola           45.0
# ..           ...            ...
# 188    Venezuela            3.0
# 189      Vietnam            1.0
# 190        Yemen            NaN
# 191       Zambia            4.0
# 192     Zimbabwe            4.0
#
# [193 rows x 2 columns]

# %%
alcohol = pd.read_csv('https://www.andybek.com/pandas-drinks', usecols=['country', 'wine_servings'], index_col='country')

# %%
alcohol.head()
# Out:
#              wine_servings
# country
# Afghanistan            NaN
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0

# %%
type(alcohol)
# Out:
# pandas.core.frame.DataFrame

# %%
alcohol = pd.read_csv('https://www.andybek.com/pandas-drinks', usecols=['country', 'wine_servings'], index_col='country').squeeze("columns")
type(alcohol)
# Out:
# pandas.core.series.Series

# %%
alcohol.head()
# Out:
# country
# Afghanistan      NaN
# Albania         54.0
# Algeria         14.0
# Andorra        312.0
# Angola          45.0
# Name: wine_servings, dtype: float64

# %% [markdown]
# ## 3. Series Sizing

# %%
alcohol.size
# Out:
# 193

# %%
alcohol.values
# Out:
# array([ nan,  54.,  14., 312.,  45.,  45., 221.,  11., 212., 191.,   5.,
#         51.,   7.,  nan,  36.,  42., 212.,   8.,  13.,  nan,   8.,   8.,
#         35.,  16.,   1.,  94.,   7.,  nan,   7.,  16.,   1.,   4.,   1.,
#          1.,   1., 172.,   8.,   3.,   1.,   9.,  74.,  11., 254.,   5.,
#        113., 134.,  nan,   1., 278.,   3.,  26.,   9.,   3.,   1.,   2.,
#        233.,  nan,  59.,  nan,   1.,  97.,  37.,  59.,   1., 149., 175.,
#          1., 218.,  28.,   2.,   2.,  21.,   1.,   1.,   2., 185.,  78.,
#         nan,  nan,  nan,  nan, 165.,   9., 237.,   9.,  16.,   1.,  12.,
#          2.,   1.,  nan,   6., 123.,  62.,  31.,  nan,   2.,  nan,  56.,
#        271.,   4.,   1.,  nan,  nan,   1.,  12.,  nan,  nan,  18.,   5.,
#         18.,  nan,   8., 128.,   1.,   5.,  nan,   1.,   8.,  nan,  19.,
#        175.,   1.,   1.,   2.,   7., 129.,   1.,  nan,  23.,  18.,   1.,
#         74.,  21.,   1.,  56., 339.,   7.,   9.,  18., 167.,  73.,  nan,
# ...

# %%
alcohol.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
alcohol.shape
# Out:
# (193,)

# %%
alcohol.info
# Out:
# <bound method Series.info of country
# Afghanistan      NaN
# Albania         54.0
# Algeria         14.0
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen            NaN
# Zambia           4.0
# Zimbabwe         4.0
# Name: wine_servings, Length: 193, dtype: float64>

# %%
len(alcohol)
# Out:
# 193

# %% [markdown]
# ## 5. The count() Method

# %%
alcohol.count()
# Out:
# np.int64(162)

# %%
alcohol.hasnans
# Out:
# True

# %% [markdown]
# ## 6. Accessing And Counting NAs

# %% [markdown]
# ### Count No. of NaN: Way 1

# %%
alcohol.count()
# Out:
# np.int64(162)

# %%
alcohol.isnull()
# Out:
# country
# Afghanistan     True
# Albania        False
# Algeria        False
# Andorra        False
# Angola         False
#                ...
# Venezuela      False
# Vietnam        False
# Yemen           True
# Zambia         False
# Zimbabwe       False
# Name: wine_servings, Length: 193, dtype: bool

# %%
alcohol[alcohol.isnull()]
# Out:
# country
# Afghanistan        NaN
# Bangladesh         NaN
# Bhutan             NaN
# Burundi            NaN
# North Korea        NaN
# Eritrea            NaN
# Ethiopia           NaN
# India              NaN
# Indonesia          NaN
# Iran               NaN
# Iraq               NaN
# Kuwait             NaN
# Lesotho            NaN
# Libya              NaN
# Malaysia           NaN
# Maldives           NaN
# Marshall Islands   NaN
# Mauritania         NaN
# Monaco             NaN
# Myanmar            NaN
# Nepal              NaN
# Pakistan           NaN
# Rwanda             NaN
# San Marino         NaN
# Saudi Arabia       NaN
# Somalia            NaN
# Sri Lanka          NaN
# Sudan              NaN
# Tajikistan         NaN
# Uganda             NaN
# Yemen              NaN
# Name: wine_servings, dtype: float64

# %%
alcohol[alcohol.isnull()].value_counts(dropna=False)
# Out:
# wine_servings
# NaN    31
# Name: count, dtype: int64

# %% [markdown]
# ### Count No. of NaN: Way 2

# %%
alcohol[alcohol.isnull()].size + alcohol.count()
# Out:
# np.int64(193)

# %%
alcohol.size
# Out:
# 193

# %%
alcohol[alcohol.isnull()].index
# Out:
# Index(['Afghanistan', 'Bangladesh', 'Bhutan', 'Burundi', 'North Korea',
#        'Eritrea', 'Ethiopia', 'India', 'Indonesia', 'Iran', 'Iraq', 'Kuwait',
#        'Lesotho', 'Libya', 'Malaysia', 'Maldives', 'Marshall Islands',
#        'Mauritania', 'Monaco', 'Myanmar', 'Nepal', 'Pakistan', 'Rwanda',
#        'San Marino', 'Saudi Arabia', 'Somalia', 'Sri Lanka', 'Sudan',
#        'Tajikistan', 'Uganda', 'Yemen'],
#       dtype='object', name='country')

# %%
list(alcohol[alcohol.isnull()].index)
# Out:
# ['Afghanistan',
#  'Bangladesh',
#  'Bhutan',
#  'Burundi',
#  'North Korea',
#  'Eritrea',
#  'Ethiopia',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Kuwait',
#  'Lesotho',
#  'Libya',
#  'Malaysia',
#  'Maldives',
#  'Marshall Islands',
#  'Mauritania',
#  'Monaco',
#  'Myanmar',
#  'Nepal',
#  'Pakistan',
#  'Rwanda',
#  'San Marino',
#  'Saudi Arabia',
#  'Somalia',
#  'Sri Lanka',
#  'Sudan',
#  'Tajikistan',
#  'Uganda',
#  'Yemen']

# %%
len(list(alcohol[alcohol.isnull()].index))
# Out:
# 31

# %% [markdown]
# ### Count No. of NaN: Way 3

# %%
pd.Series([False,True,True]).sum()
# Out:
# np.int64(2)

# %%
alcohol.isnull().sum()
# Out:
# np.int64(31)

# %% [markdown]
# ## 8. The Other Side notnull() And notna()

# %%
alcohol.notna().sum()
# Out:
# np.int64(162)

# %%
alcohol.notna().sum()+ alcohol.isnull().sum()
# Out:
# np.int64(193)

# %%
alcohol.size
# Out:
# 193

# %% [markdown]
# ## 10. Skill Challenge

# %% [markdown]
# ### 1. Isolate the non-nulls in the **alcohol** series

# %%
wine_serving = alcohol[alcohol.notnull()]

# %% [markdown]
# ### 2. What is the total wine consume by each contries in wine_serving

# %%
wine_serving
# Out:
# country
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
#                      ...
# Vanuatu               11.0
# Venezuela              3.0
# Vietnam                1.0
# Zambia                 4.0
# Zimbabwe               4.0
# Name: wine_servings, Length: 162, dtype: float64

# %%
wine_serving.sum()
# Out:
# np.float64(8221.0)

# %% [markdown]
# ### 3. Show total less than wine consume by contries

# %%
wine_serving < 100
# Out:
# country
# Albania               True
# Algeria               True
# Andorra              False
# Angola                True
# Antigua & Barbuda     True
#                      ...
# Vanuatu               True
# Venezuela             True
# Vietnam               True
# Zambia                True
# Zimbabwe              True
# Name: wine_servings, Length: 162, dtype: bool

# %%
wine_serving[wine_serving < 100]
# Out:
# country
# Albania              54.0
# Algeria              14.0
# Angola               45.0
# Antigua & Barbuda    45.0
# Armenia              11.0
#                      ...
# Vanuatu              11.0
# Venezuela             3.0
# Vietnam               1.0
# Zambia                4.0
# Zimbabwe              4.0
# Name: wine_servings, Length: 132, dtype: float64

# %%
wine_serving[wine_serving < 100].sum()
# Out:
# np.float64(2416.0)

# %% [markdown]
# ## 12. Dropping and Filling NAs

# %%
alcohol.dropna()
# Out:
# country
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
#                      ...
# Vanuatu               11.0
# Venezuela              3.0
# Vietnam                1.0
# Zambia                 4.0
# Zimbabwe               4.0
# Name: wine_servings, Length: 162, dtype: float64

# %%
temp = alcohol.fillna(0)
temp
# Out:
# country
# Afghanistan      0.0
# Albania         54.0
# Algeria         14.0
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen            0.0
# Zambia           4.0
# Zimbabwe         4.0
# Name: wine_servings, Length: 193, dtype: float64

# %%
temp[temp == 0].size
# Out:
# 31

# %%
temp[temp != 0].size
# Out:
# 162

# %% [markdown]
# ## 13.Descriptive statistics

# %%
alcohol.mean()
# Out:
# np.float64(50.74691358024691)

# %%
# return middle ELEMENT AFTER SORTED VALUE
alcohol.median()
# Out:
# 11.5

# %%
# return most repeated value
alcohol.mode()
# Out:
# 0    1.0
# Name: wine_servings, dtype: float64

# %%
alcohol.min()
# Out:
# 1.0

# %%
alcohol.max()
# Out:
# 339.0

# %%
alcohol.describe()
# Out:
# count    162.000000
# mean      50.746914
# std       76.134917
# min        1.000000
# 25%        3.000000
# 50%       11.500000
# 75%       61.250000
# max      339.000000
# Name: wine_servings, dtype: float64

# %% [markdown]
# ## 14. mode() and count that value

# %%
alcohol.mode()
# Out:
# 0    1.0
# Name: wine_servings, dtype: float64

# %%
alcohol == 1
# Out:
# country
# Afghanistan    False
# Albania        False
# Algeria        False
# Andorra        False
# Angola         False
#                ...
# Venezuela      False
# Vietnam         True
# Yemen          False
# Zambia         False
# Zimbabwe       False
# Name: wine_servings, Length: 193, dtype: bool

# %%
# count of that mode value
alcohol[alcohol==1].size
# Out:
# 28

# %%
alcohol.value_counts()
# Out:
# wine_servings
# 1.0      28
# 2.0      10
# 7.0       9
# 8.0       7
# 5.0       6
#          ..
# 218.0     1
# 185.0     1
# 78.0      1
# 165.0     1
# 22.0      1
# Name: count, Length: 71, dtype: int64

# %% [markdown]
# ## 16. idxmax() And idxmin()

# %% [markdown]
# ### way 1

# %%
alcohol.max()
# Out:
# 339.0

# %%
alcohol == alcohol.max()
# Out:
# country
# Afghanistan    False
# Albania        False
# Algeria        False
# Andorra        False
# Angola         False
#                ...
# Venezuela      False
# Vietnam        False
# Yemen          False
# Zambia         False
# Zimbabwe       False
# Name: wine_servings, Length: 193, dtype: bool

# %%
alcohol[alcohol == alcohol.max()]
# Out:
# country
# Portugal    339.0
# Name: wine_servings, dtype: float64

# %%
alcohol[alcohol == alcohol.max()].index[0]
# Out:
# 'Portugal'

# %% [markdown]
# ### way 2

# %%
alcohol.idxmax()
# Out:
# 'Portugal'

# %%
alcohol.idxmin()
# Out:
# 'Brunei'

# %% [markdown]
# ### but

# %%
alcohol[alcohol==alcohol.min()].value_counts()
# Out:
# wine_servings
# 1.0    28
# Name: count, dtype: int64

# %%
alcohol[alcohol==alcohol.min()]
# Out:
# country
# Brunei                      1.0
# Cambodia                    1.0
# Canada                      1.0
# Central African Republic    1.0
# Chad                        1.0
# Comoros                     1.0
# DR Congo                    1.0
# Egypt                       1.0
# Fiji                        1.0
# Gambia                      1.0
# Ghana                       1.0
# Guyana                      1.0
# Haiti                       1.0
# Jordan                      1.0
# Kiribati                    1.0
# Malawi                      1.0
# Mali                        1.0
# Morocco                     1.0
# Namibia                     1.0
# Nicaragua                   1.0
# Niger                       1.0
# Oman                        1.0
# Papua New Guinea            1.0
# Philippines                 1.0
# Solomon Islands             1.0
# Thailand                    1.0
# Tanzania                    1.0
# Vietnam                     1.0
# Name: wine_servings, dtype: float64

# %% [markdown]
# ## 17. Sorting

# %%
alcohol.sort_values()
# Out:
# country
# Thailand           1.0
# Solomon Islands    1.0
# Brunei             1.0
# Haiti              1.0
# Cambodia           1.0
#                   ...
# Sri Lanka          NaN
# Sudan              NaN
# Tajikistan         NaN
# Uganda             NaN
# Yemen              NaN
# Name: wine_servings, Length: 193, dtype: float64

# %%
alcohol[alcohol.notnull()].sort_values()
# Out:
# country
# Thailand             1.0
# Solomon Islands      1.0
# Brunei               1.0
# Haiti                1.0
# Cambodia             1.0
#                    ...
# Luxembourg         271.0
# Slovenia           276.0
# Denmark            278.0
# Andorra            312.0
# Portugal           339.0
# Name: wine_servings, Length: 162, dtype: float64

# %%
alcohol[alcohol.notnull()].sort_values().head(30)
# Out:
# country
# Thailand                    1.0
# Solomon Islands             1.0
# Brunei                      1.0
# Haiti                       1.0
# Cambodia                    1.0
# Guyana                      1.0
# Canada                      1.0
# Jordan                      1.0
# Central African Republic    1.0
# Comoros                     1.0
# Ghana                       1.0
# Gambia                      1.0
# Fiji                        1.0
# Egypt                       1.0
# DR Congo                    1.0
# Chad                        1.0
# Kiribati                    1.0
# Tanzania                    1.0
# Philippines                 1.0
# Vietnam                     1.0
# Papua New Guinea            1.0
# Oman                        1.0
# Malawi                      1.0
# Mali                        1.0
# Morocco                     1.0
# Namibia                     1.0
# Nicaragua                   1.0
# Niger                       1.0
# Kenya                       2.0
# ...
