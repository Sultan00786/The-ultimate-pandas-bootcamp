# %% [markdown]
# ### 1.

# %%
import pandas as pd
squares = pd.Series(data=[i*i for i in range(100)])
squares
# Out:
# 0        0
# 1        1
# 2        4
# 3        9
# 4       16
#       ...
# 95    9025
# 96    9216
# 97    9409
# 98    9604
# 99    9801
# Length: 100, dtype: int64

# %% [markdown]
# ### 2.

# %%
op1=squares[-3:]
op1
# Out:
# 97    9409
# 98    9604
# 99    9801
# dtype: int64

# %% [markdown]
# ### 3.

# %%
op2=squares.tail(3)
op2
# Out:
# 97    9409
# 98    9604
# 99    9801
# dtype: int64

# %% [markdown]
# ### 4.

# %%
op1.equals(op2)
# Out:
# True
