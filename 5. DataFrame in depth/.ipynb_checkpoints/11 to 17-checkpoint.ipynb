# %% [markdown]
# ### 11. 2d Indexing

# %%
import pandas as pd
import numpy as np
data_url = 'https://andybek.com/pandas-soccer'
players = pd.read_csv(data_url)
players.head(6)
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
# 5    Hector Bellerin  Arsenal   22       RB             3          30.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
# ...

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          465 non-null    object
#  1   club          465 non-null    object
#  2   age           465 non-null    int64
#  3   position      464 non-null    object
#  4   position_cat  465 non-null    int64
#  5   market_value  462 non-null    float64
#  6   page_views    465 non-null    int64
#  7   fpl_value     465 non-null    float64
#  8   fpl_sel       465 non-null    object
#  9   fpl_points    465 non-null    int64
#  10  region        465 non-null    int64
#  11  nationality   465 non-null    object
#  12  new_foreign   465 non-null    int64
#  13  age_cat       465 non-null    int64
#  14  club_id       465 non-null    int64
#  15  big_club      465 non-null    int64
#  16  new_signing   465 non-null    int64
# dtypes: float64(2), int64(10), object(5)
# ...

# %%
players.club.unique()
# Out:
# array(['Arsenal', 'Bournemouth', 'Brighton+and+Hove', 'Burnley',
#        'Chelsea', 'Crystal+Palace', 'Everton', 'Huddersfield',
#        'Leicester+City', 'Liverpool', 'Manchester+City',
#        'Manchester+United', 'Newcastle+United', 'Southampton',
#        'Stoke+City', 'Swansea', 'Tottenham', 'Watford', 'West+Brom',
#        'West+Ham'], dtype=object)

# %%
# Chelsea players which has age of 23 years or younger
condition_1 = (players.club == 'Chelsea') & (players.age <= 23)
players[condition_1]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 110   Michy Batshuayi  Chelsea   23       CF             1          25.0
# 111        Kurt Zouma  Chelsea   22       CB             3          15.0
# 112            Kenedy  Chelsea   21       LB             3           7.0
# 115  Tiemoue Bakayoko  Chelsea   22       DM             2          16.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 110        1162        8.5   1.60%          48       2     Belgium
# 111         723        5.5   0.80%          15       2      France
# 112         566        5.0   0.10%           3       3      Brazil
# 115        1011        5.0   1.60%           0       2      France
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 110            0        2        5         1            1
# 111            0        2        5         1            0
# 112            0        1        5         1            0
# ...

# %%
coll_arr = ['name', 'club', 'age', 'position', 'market_value']
players.loc[condition_1, coll_arr]
# Out:
#                  name     club  age position  market_value
# 110   Michy Batshuayi  Chelsea   23       CF          25.0
# 111        Kurt Zouma  Chelsea   22       CB          15.0
# 112            Kenedy  Chelsea   21       LB           7.0
# 115  Tiemoue Bakayoko  Chelsea   22       DM          16.0

# %% [markdown]
# ### 13. Sorting By Index Or Colm

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          465 non-null    object
#  1   club          465 non-null    object
#  2   age           465 non-null    int64
#  3   position      464 non-null    object
#  4   position_cat  465 non-null    int64
#  5   market_value  462 non-null    float64
#  6   page_views    465 non-null    int64
#  7   fpl_value     465 non-null    float64
#  8   fpl_sel       465 non-null    object
#  9   fpl_points    465 non-null    int64
#  10  region        465 non-null    int64
#  11  nationality   465 non-null    object
#  12  new_foreign   465 non-null    int64
#  13  age_cat       465 non-null    int64
#  14  club_id       465 non-null    int64
#  15  big_club      465 non-null    int64
#  16  new_signing   465 non-null    int64
# dtypes: float64(2), int64(10), object(5)
# ...

# %%
players.sort_values(by=['market_value'], ascending=False)
# Out:
#                     name               club  age position  position_cat  \
# 96           Eden Hazard            Chelsea   26       LW             1
# 267           Paul Pogba  Manchester+United   24       CM             2
# 0         Alexis Sanchez            Arsenal   28       LW             1
# 244      Kevin De Bruyne    Manchester+City   26       AM             1
# 245        Sergio Aguero    Manchester+City   29       CF             1
# ..                   ...                ...  ...      ...           ...
# 287  Joel Castro Pereira  Manchester+United   21       GK             4
# 113     Eduardo Carvalho            Chelsea   34       LW             1
# 30          Granit Xhaka            Arsenal   24      NaN             2
# 192         Steve Mounie       Huddersfield   22       CF             1
# 195    Kasper Schmeichel     Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %% [markdown]
# players.set_index('name',inplace=True)

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.sort_index()
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.sort_index(axis=1)
# Out:
#      age  age_cat  big_club      club  club_id  fpl_points fpl_sel  fpl_value  \
# 0     28        4         1   Arsenal        1         264  17.10%       12.0
# 1     28        4         1   Arsenal        1         167   5.60%        9.5
# 2     35        6         1   Arsenal        1         134   5.90%        5.5
# 3     28        4         1   Arsenal        1         122   1.50%        7.5
# 4     31        4         1   Arsenal        1         121   0.70%        6.0
# ..   ...      ...       ...       ...      ...         ...     ...        ...
# 460   21        1         0  West+Ham       20          38   0.40%        4.5
# 461   23        2         0  West+Ham       20          34   0.20%        4.5
# 462   23        2         0  West+Ham       20          29   0.30%        4.5
# 463   21        1         0  West+Ham       20          16   5.90%        4.5
# 464   27        3         0  West+Ham       20          12   0.10%        5.5
#
# ...

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.reset_index()
# Out:
#      index                 name      club  age position  position_cat  \
# 0        0       Alexis Sanchez   Arsenal   28       LW             1
# 1        1           Mesut Ozil   Arsenal   28       AM             1
# 2        2            Petr Cech   Arsenal   35       GK             4
# 3        3         Theo Walcott   Arsenal   28       RW             1
# 4        4    Laurent Koscielny   Arsenal   31       CB             3
# ..     ...                  ...       ...  ...      ...           ...
# 460    460  Edimilson Fernandes  West+Ham   21       CM             2
# 461    461       Arthur Masuaku  West+Ham   23       LB             3
# 462    462            Sam Byram  West+Ham   23       RB             3
# 463    463      Ashley Fletcher  West+Ham   21       CF             1
# 464    464         Diafra Sakho  West+Ham   27       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %% [markdown]
# ### 17. Skill Challenge

# %% [markdown]
# #### 1. Sort the players datame by age in ascending order. Who is the youngest footballer in the EPL

# %%
players.sort_values(by=['age']).head()
# Out:
#                        name               club  age position  position_cat  \
# 237            Ben Woodburn          Liverpool   17       LW             1
# 354              Josh Tymon         Stoke+City   18       LB             3
# 439           Jonathan Leko          West+Brom   18       RW             1
# 235  Trent Alexander-Arnold          Liverpool   18       RB             3
# 274         Marcus Rashford  Manchester+United   19       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 237           1.5        1241        4.5   0.10%           5       1
# 354           1.0         120        4.5   0.10%           9       1
# 439           1.5         169        4.5   0.20%          12       1
# 235           1.5         327        4.5   0.30%          15       2
# 274          18.0        3668        7.5   4.80%          76       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# ...

# %% [markdown]
# #### 2. Set the club colm as index of the DF. Then sort the dataframe index in alphabetical order.

# %%
# players.set_index('club',inplace=True)
players.set_index('club',inplace=True)

# %%
# players.set_index('club',inplace=True)
players.sort_index().head()
# Out:
#                       name  age position  position_cat  market_value  \
# club
# Arsenal     Alexis Sanchez   28       LW             1          65.0
# Arsenal         Mesut Ozil   28       AM             1          50.0
# Arsenal          Petr Cech   35       GK             4           7.0
# Arsenal       Theo Walcott   28       RW             1          20.0
# Arsenal  Laurent Koscielny   31       CB             3          22.0
#
#          page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# club
# Arsenal        4329       12.0  17.10%         264       3           Chile
# Arsenal        4395        9.5   5.60%         167       2         Germany
# Arsenal        1529        5.5   5.90%         134       2  Czech Republic
# Arsenal        2393        7.5   1.50%         122       1         England
# Arsenal         912        6.0   0.70%         121       2          France
#
#          new_foreign  age_cat  club_id  big_club  new_signing
# club
# ...

# %%
players = players.reset_index()

# %% [markdown]
# #### 3. Sort the df values by club and market_value where the club is alphabetical and the market value is descending order.

# %%
players.sort_values(by=['club','market_value'], ascending=[True,False]).head()
# Out:
#        club                 name  age position  position_cat  market_value  \
# 0   Arsenal       Alexis Sanchez   28       LW             1          65.0
# 1   Arsenal           Mesut Ozil   28       AM             1          50.0
# 31  Arsenal  Alexandre Lacazette   26       CF             1          40.0
# 10  Arsenal         Granit Xhaka   24       DM             2          35.0
# 11  Arsenal         Granit Xhaka   24       DM             2          35.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 0         4329       12.0  17.10%         264       3        Chile
# 1         4395        9.5   5.60%         167       2      Germany
# 31        1183       10.5  26.50%           0       2       France
# 10        1815        5.5   2.00%          85       2  Switzerland
# 11        1815        5.5   2.00%          85       2  Switzerland
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# ...
