# %%
import pandas as pd
import numpy as np
data_url = 'https://andybek.com/pandas-soccer'
players = pd.read_csv(data_url)
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %% [markdown]
# ### 36. Setting DataFrame Values

# %%
players.loc[0,'age'] = 2800
players.head(1)
# Out:
#              name     club   age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal  2800       LW             1          65.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
#
#    age_cat  club_id  big_club  new_signing
# 0        4        1         1            0

# %%
players.iloc[0,2] = 28
players.head(1)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
#
#    age_cat  club_id  big_club  new_signing
# 0        4        1         1            0

# %% [markdown]
# ### 39. Adding DataFrame Columns

# %%
players.columns
# Out:
# Index(['name', 'club', 'age', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing'],
#       dtype='object')

# %%
players['mv_by_fpl'] =  players.market_value/players.fpl_value
players.loc[:,['market_value','fpl_value','mv_by_fpl',]].head()
# Out:
#    market_value  fpl_value  mv_by_fpl
# 0          65.0       12.0   5.416667
# 1          50.0        9.5   5.263158
# 2           7.0        5.5   1.272727
# 3          20.0        7.5   2.666667
# 4          22.0        6.0   3.666667

# %%
players.columns
# Out:
# Index(['name', 'club', 'age', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing', 'mv_by_fpl'],
#       dtype='object')

# %% [markdown]
# #### **Easy Way**:

# %%
temp = players.iloc[0:5, 1:5]
temp
# Out:
#       club  age position  position_cat
# 0  Arsenal   28       LW             1
# 1  Arsenal   28       AM             1
# 2  Arsenal   35       GK             4
# 3  Arsenal   28       RW             1
# 4  Arsenal   31       CB             3

# %%
players_name = pd.Series(['R', 'M', 'N', 'H'])
mv_by_fpl =  players.market_value/players.fpl_value

print(type(players_name))
print(type(mv_by_fpl))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
###
temp.insert(0,'name',players_name)
temp
# Out:
#   name     club  age position  position_cat
# 0    R  Arsenal   28       LW             1
# 1    M  Arsenal   28       AM             1
# 2    N  Arsenal   35       GK             4
# 3    H  Arsenal   28       RW             1
# 4  NaN  Arsenal   31       CB             3

# %%
temp.insert([0,2],['name','mv_by_fpl'],[players_name, mv_by_fpl])
temp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 temp.insert([0,2],['name','mv_by_fpl'],[players_name, mv_by_fpl])
#       2 temp
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5178, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    5173 if allow_duplicates and not self.flags.allows_duplicate_labels:
#    5174     raise ValueError(
#    5175         "Cannot specify 'allow_duplicates=True' when "
#    5176         "'self.flags.allows_duplicate_labels' is False."
#    5177     )
# -> 5178 if not allow_duplicates and column in self.columns:
#    5179     # Should this be a different kind of error??
#    5180     raise ValueError(f"cannot insert {column}, already exists")
#    5181 if not is_integer(loc):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5370, in Index.__contains__(self, key)
# ...

# %%
temp.assign(name2=players_name, mv_by_fpl=mv_by_fpl)
# Out:
#   name     club  age position  position_cat name2  mv_by_fpl
# 0    R  Arsenal   28       LW             1     R   5.416667
# 1    M  Arsenal   28       AM             1     M   5.263158
# 2    N  Arsenal   35       GK             4     N   1.272727
# 3    H  Arsenal   28       RW             1     H   2.666667
# 4  NaN  Arsenal   31       CB             3   NaN   3.666667

# %% [markdown]
# ### 40. Adding Rows To DataFrames (Inefficient and Expensive Operation)

# %%
temp
# Out:
#   name     club  age position  position_cat
# 0    R  Arsenal   28       LW             1
# 1    M  Arsenal   28       AM             1
# 2    N  Arsenal   35       GK             4
# 3    H  Arsenal   28       RW             1
# 4  NaN  Arsenal   31       CB             3

# %%
players.club.unique()
# Out:
# array(['Arsenal', 'Bournemouth', 'Brighton+and+Hove', 'Burnley',
#        'Chelsea', 'Crystal+Palace', 'Everton', 'Huddersfield',
#        'Leicester+City', 'Liverpool', 'Manchester+City',
#        'Manchester+United', 'Newcastle+United', 'Southampton',
#        'Stoke+City', 'Swansea', 'Tottenham', 'Watford', 'West+Brom',
#        'West+Ham'], dtype=object)

# %%
cristiano = pd.Series({
    'name': 'C',
    'club': 'Chelsea',
    'age': 40,
    'position': 'RW',
    'position_cat': 2,
}, name=5)
cristiano
# Out:
# name                  C
# club            Chelsea
# age                  40
# position             RW
# position_cat          2
# Name: 5, dtype: object

# %%
### Removed from old version
temp.append(cristiano)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9876\2946804377.py in ?()
#       1 ###
# ----> 2 temp.append(cristiano)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
###
pd.DataFrame([cristiano])
# Out:
#   name     club  age position  position_cat
# 5    C  Chelsea   40       RW             2

# %%
###
pd.concat([temp, pd.DataFrame([cristiano])])
# Out:
#   name     club  age position  position_cat
# 0    R  Arsenal   28       LW             1
# 1    M  Arsenal   28       AM             1
# 2    N  Arsenal   35       GK             4
# 3    H  Arsenal   28       RW             1
# 4  NaN  Arsenal   31       CB             3
# 5    C  Chelsea   40       RW             2
