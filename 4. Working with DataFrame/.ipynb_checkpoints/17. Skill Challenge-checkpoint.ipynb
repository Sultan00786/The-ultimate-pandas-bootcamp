# %%
import pandas as pd
data_url = 'https://andybek.com/pandas-nutrition'
df = pd.read_csv(data_url)
df
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                         Cornstarch
# 1              1                                       Nuts, pecans
# 2              2                                      Eggplant, raw
# 3              3                                     Teff, uncooked
# 4              4                                    Sherbet, orange
# ...          ...                                                ...
# 8784        8784  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8785        8785  Lamb, cooked, separable lean only, composite o...
# 8786        8786  Lamb, raw, separable lean and fat, composite o...
# 8787        8787  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8788        8788  Beef, raw, all grades, trimmed to 0" fat, sepa...
#
#      serving_size  calories total_fat saturated_fat cholesterol    sodium  \
# 0           100 g       381      0.1g           NaN           0   9.00 mg
# ...

# %% [markdown]
# ### 1. Get Random 10 row to new var nutri_mini

# %%
#random 10 row
nu_mini=df.sample(10)
nu_mini
# Out:
#       Unnamed: 0                                               name  \
# 7649        7649  Beef, broiled, cooked, select, trimmed to 0" f...
# 1836        1836                    Alcoholic beverage, rice (sake)
# 1976        1976                     MOTHER'S, Iced Oatmeal Cookies
# 7127        7127  Squash, without salt, drained, boiled, cooked,...
# 6625        6625  Cereals ready-to-eat, CAP'N CRUNCH'S PEANUT BU...
# 8082        8082  Pork, roasted, cooked, separable lean only, bo...
# 8001        8001  Infant formula, with ARA and DHA, ready-to-fee...
# 1816        1816                    Emu, broiled, cooked, full rump
# 8669        8669  Beef, raw, select, trimmed to 1/8" fat, separa...
# 40            40                             Gravy, mix, dry, onion
#
#      serving_size  calories total_fat saturated_fat cholesterol      sodium  \
# 7649        100 g       177      7.4g          2.8g        80mg    71.00 mg
# ...

# %% [markdown]
# ### 2. Extract total_fat and cholestrol form the nu_mini var

# %%
nu_mini.loc[:, ['total_fat','cholesterol']]
# Out:
#      total_fat cholesterol
# 7649      7.4g        80mg
# 1836        0g           0
# 1976       18g         1mg
# 7127      0.4g           0
# 6625      9.2g           0
# 8082       10g        83mg
# 8001      3.5g         1mg
# 1816      2.7g       129mg
# 8669       11g        68mg
# 40          3g         2mg

# %% [markdown]
# ### 3. Extract all colm from vitamin_b12 to end, for 1st, 2nd and 3rd row

# %%
nu_mini.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 7649 to 40
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   10 non-null     int64
#  1   name                         10 non-null     object
#  2   serving_size                 10 non-null     object
#  3   calories                     10 non-null     int64
#  4   total_fat                    10 non-null     object
#  5   saturated_fat                9 non-null      object
#  6   cholesterol                  10 non-null     object
#  7   sodium                       10 non-null     object
#  8   choline                      10 non-null     object
#  9   folate                       10 non-null     object
#  10  folic_acid                   10 non-null     object
#  11  niacin                       10 non-null     object
#  12  pantothenic_acid             10 non-null     object
# ...

# %%
nu_mini.iloc[0:3, 22:]
# Out:
#      vitamin_b12 vitamin_b6 vitamin_c vitamin_d vitamin_e tocopherol_alpha  \
# 7649    2.27 mcg   0.390 mg    0.0 mg         0   0.14 mg          0.14 mg
# 1836    0.00 mcg   0.000 mg    0.0 mg   0.00 IU   0.00 mg          0.00 mg
# 1976           0   0.010 mg         0         0         0                0
#
#      vitamin_k  calcium    copper     irom  ...      fat  \
# 7649         0  4.00 mg  0.143 mg  3.66 mg  ...   7.36 g
# 1836   0.0 mcg  5.00 mg  0.009 mg  0.10 mg  ...   0.00 g
# 1976         0        0         0  2.30 mg  ...  18.00 g
#
#      saturated_fatty_acids monounsaturated_fatty_acids  \
# 7649               2.820 g                     3.340 g
# 1836               0.000 g                     0.000 g
# 1976               5.800 g                     4.200 g
#
#      polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 7649                     0.380 g                80.00 mg   0.0 g  1.20 g
# ...

# %% [markdown]
# ### 4. Get calories for 3rd food in nu_mini

# %%
nu_mini.iloc[2,3]
# Out:
# np.int64(463)
